# %%
# !pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ----- ---------------------------------- 5.0/39.5 MB 24.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 10.0/39.5 MB 24.6 MB/s eta 0:00:02
#    --------------- ------------------------ 15.2/39.5 MB 24.4 MB/s eta 0:00:01
#    -------------------- ------------------- 20.7/39.5 MB 24.7 MB/s eta 0:00:01
#    -------------------------- ------------- 26.0/39.5 MB 24.8 MB/s eta 0:00:01
#    ------------------------------- -------- 31.2/39.5 MB 24.9 MB/s eta 0:00:01
#    ------------------------------------ --- 36.2/39.5 MB 25.0 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 25.0 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 23.4 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

# %%
# Read an Image

img = cv2.imread('KNN/dog.png')

newImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
from matplotlib import pyplot as plt
plt.imshow(img)
plt.show()
plt.imshow(newImg)
plt.show()
